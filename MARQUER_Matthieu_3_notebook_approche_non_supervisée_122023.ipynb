# %% [markdown]
# # MARQUER Matthieu
# ## Projet 5: Catégorisez automatiquement des questions
#  ![alt text](img/16480242457412.png "Stack Overflow")
#  Part: 3 Approche non supervisée

# %% [markdown]
# ### Importation des librairies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Modification des options

# %%
# https://pandas.pydata.org/docs/reference/api/pandas.set_option.html
#pd.set_option("display.max_rows", 200)
#pd.set_option("display.max_colwidth", 500)
#pd.set_option('display.max_columns', 100)

# %% [markdown]
# ### Importation des fichiers

# %%
data = pd.read_csv('data/cleaned/data_cleaned.csv')
data.head(3)
# Out:
#          Id                                              Title  \
# 0  11227809  Why is processing a sorted array faster than p...
# 1   2003505  How do I delete a Git branch locally and remot...
# 2   1642028               What is the '-->' operator in C/C++?
#
#                                                 Body  \
# 0  <p>In this C++ code, sorting the data (<em>bef...
# 1  <p>Failed Attempts to Delete a Remote Branch:<...
# 2  <p>After reading <a href="http://groups.google...
#
#                                                 Tags  Score  ViewCount  \
# 0  <java><c++><performance><cpu-architecture><bra...  27160    1851289
# 1  <git><version-control><git-branch><git-push><g...  20380   11236108
# 2  <c++><c><operators><code-formatting><standards...  10112     994570
#
#    FavoriteCount  AnswerCount         CreationDate  \
# 0            0.0           25  2012-06-27 13:51:36
# 1            0.0           41  2010-01-05 01:12:15
# 2            0.0           26  2009-10-29 06:57:45
#
#                                           Title_Body
# 0  Why processing sorted array faster processing ...
# 1  How delete Git branch locally remotely Failed ...
# 2  What operator After reading Hidden Features Da...

# %%
# Nombre de lignes et de colonnes
data.shape
# Out:
# (50000, 10)

# %%
data.describe(include="all")
# Out:
#                   Id                                              Title  \
# count   5.000000e+04                                              50000
# unique           NaN                                              49999
# top              NaN  A potentially dangerous Request.Form value was...
# freq             NaN                                                  2
# mean    2.204007e+07                                                NaN
# std     1.824021e+07                                                NaN
# min     4.000000e+00                                                NaN
# 25%     6.153363e+06                                                NaN
# 50%     1.760211e+07                                                NaN
# 75%     3.492368e+07                                                NaN
# max     7.762431e+07                                                NaN
#
#                                                      Body  \
# count                                               50000
# unique                                              50000
# top     <p>In this C++ code, sorting the data (<em>bef...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                      Tags         Score  \
# count                                               50000  50000.000000
# unique                                              48706           NaN
# top     <javascript><jquery><html><css><twitter-bootst...           NaN
# freq                                                   31           NaN
# mean                                                  NaN     85.186840
# std                                                   NaN    283.783728
# min                                                   NaN     20.000000
# 25%                                                   NaN     26.000000
# 50%                                                   NaN     37.000000
# 75%                                                   NaN     68.000000
# max                                                   NaN  27160.000000
#
#            ViewCount  FavoriteCount   AnswerCount         CreationDate  \
# count   5.000000e+04   49293.000000  50000.000000                50000
# unique           NaN            NaN           NaN                49994
# top              NaN            NaN           NaN  2013-07-12 13:28:17
# freq             NaN            NaN           NaN                    2
# mean    9.006724e+04       0.000811      6.177000                  NaN
# std     2.173949e+05       0.144692      5.933739                  NaN
# min     2.060000e+02       0.000000      1.000000                  NaN
# 25%     1.779975e+04       0.000000      3.000000                  NaN
# 50%     3.920550e+04       0.000000      5.000000                  NaN
# 75%     8.635250e+04       0.000000      8.000000                  NaN
# max     1.123611e+07      32.000000    140.000000                  NaN
#
#                                                Title_Body
# count                                               50000
# unique                                              50000
# top     Why processing sorted array faster processing ...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN

# %%
# Types
data.dtypes
# Out:
# Id                 int64
# Title             object
# Body              object
# Tags              object
# Score              int64
# ViewCount          int64
# FavoriteCount    float64
# AnswerCount        int64
# CreationDate      object
# Title_Body        object
# dtype: object

# %%
# Nombre de valeur manquantes par colonne
data.isna().sum()
# Out:
# Id                 0
# Title              0
# Body               0
# Tags               0
# Score              0
# ViewCount          0
# FavoriteCount    707
# AnswerCount        0
# CreationDate       0
# Title_Body         0
# dtype: int64

# %%
# Nombre de valeur differentes par colonne
data.nunique()
# Out:
# Id               50000
# Title            49999
# Body             50000
# Tags             48706
# Score             1148
# ViewCount        41263
# FavoriteCount        3
# AnswerCount         79
# CreationDate     49994
# Title_Body       50000
# dtype: int64

# %%
# Défini le nombre de lignes souhaitées
limite = 20000
data = data.sample(n=limite, random_state=42)

# %%
# Recuperation des tags
import re

tags = data["Tags"].apply(lambda x: re.findall(r'<(.*?)>', x))
tags
# Out:
# 33553             [python, plugins, pycharm, pep8, flake8]
# 9427                     [c#, file, io, filesystems, copy]
# 199            [unix, ssh, passwords, openssh, passphrase]
# 12447    [ios, uiview, core-animation, uiviewanimation,...
# 39489    [c#, asp.net, asp.net-mvc, visual-studio, msbu...
#                                ...
# 14324    [ios, xcode, facebook, swift, facebook-graph-api]
# 43453    [python, nlp, cluster-analysis, word2vec, word...
# 29499    [csv, apache-spark, header, apache-spark-sql, ...
# 42681    [javascript, google-chrome, google-chrome-exte...
# 42326        [python, python-3.x, cygwin, pip, python-3.4]
# Name: Tags, Length: 20000, dtype: object

# %%
# Concatenation de tags
tags_global = [tag for sublist in tags for tag in sublist]

# Nombre d'apparition de chaque tag 
from collections import Counter
tags_global = Counter(tags_global)

# Tags par ordre des plus utilisé au moins utilisé
tags_decroissant = sorted(tags_global.items(), key=lambda x: x[1], reverse=True)

# Top 50 des tags les plus utilisé
tags_top_50 = tags_decroissant[:50]

# Dataframe de tags_top_50
tags_top_50 = pd.DataFrame(tags_top_50)

# list top 50
top_50_list = set(tags_top_50[0])

# %% [markdown]
# ### Suppression des < et > sur Tags

# %%
# Garde seulement les tags du top 50 sur la variable Tags
import re

# Fonction pour filtrer les tags
def filter_tags(tags):
    return [tag for tag in re.findall(r'<(.*?)>', tags) if tag in top_50_list]

# Applique la fonction de filtre à la colonne "Tags"
data['Tags'] = data['Tags'].apply(filter_tags)

# Supprime les tags ayant plus de 25 caractères
data['Tags'] = data['Tags'].apply(lambda tags: [tag for tag in tags if len(tag) <= 25])

# Supprime les lignes sans tags
data = data[data['Tags'].apply(len) > 1]
data
# Out:
#              Id                                              Title  \
# 39489  49028212             Precompile asp.net views with ms build
# 10822   2875429  IUnityContainer.Resolve<T> throws error claimi...
# 4144    1235958              IPC performance: Named Pipe vs Socket
# 38695  30525184                    Array vs Slice: accessing speed
# 29282  30386317  Babelify throws ParseError on import a module ...
# ...         ...                                                ...
# 5477   27828822  Can't understand this way to calculate the squ...
# 43235  28865222  Mapping Java boolean to Oracle Number column w...
# 33186  50951779  Angular 2+ wait for subscribe to finish to upd...
# 14324  32031677  Facebook Graph API GET request - Should contai...
# 42326  39129450  What is the correct format to upgrade pip3 whe...
#
#                                                     Body  \
# 39489  <p>When I deploy asp.net application through v...
# 10822  <p>Yesterday I've implemented the code:</p>\n\...
# 4144   <p>Everyone seems to say named pipes are faste...
# 38695  <p>This question is about the speed of <em>acc...
# 29282  <p>I'm working with <code>Babelify</code> and ...
# ...                                                  ...
# 5477   <p>I have found a function that calculates squ...
# 43235  <p>I have a property created like this in my m...
# 33186  <p>I am having an issue with my variables bein...
# 14324  <p>My iOS app uses Facebook's Graph API Reques...
# 42326  <p>I develop for both <code>Python 2</code> an...
#
#                                             Tags  Score  ViewCount  \
# 39489  [c#, asp.net, asp.net-mvc, visual-studio]     25      14467
# 10822                                 [c#, .net]     77      40728
# 4144                        [linux, performance]    169     140521
# 38695                      [arrays, performance]     25      10443
# 29282                      [javascript, node.js]     32      19613
# ...                                          ...    ...        ...
# 5477                                 [c, arrays]    135       9480
# 43235                           [java, database]     23      32847
# 33186                      [javascript, angular]     29     106864
# 14324                        [ios, xcode, swift]     60      47952
# 42326                       [python, python-3.x]     23      62360
#
#        FavoriteCount  AnswerCount         CreationDate  \
# 39489            0.0            1  2018-02-28 11:12:01
# 10822            0.0            5  2010-05-20 15:46:20
# 4144             0.0           12  2009-08-05 21:52:24
# 38695            0.0            3  2015-05-29 08:49:35
# 29282            0.0            3  2015-05-21 23:58:19
# ...              ...          ...                  ...
# 5477             0.0            5  2015-01-07 21:18:20
# 43235            0.0            2  2015-03-04 21:21:35
# 33186            0.0            2  2018-06-20 15:23:12
# 14324            0.0            5  2015-08-16 03:58:10
# 42326            0.0            2  2016-08-24 17:20:10
#
#                                               Title_Body
# 39489  Precompile aspnet views build When deploy aspn...
# 10822  IUnityContainerResolve throws error claiming c...
# 4144   IPC performance Named Pipe Socket Everyone see...
# 38695  Array Slice accessing speed This question spee...
# 29282  Babelify throws ParseError import module nodem...
# ...                                                  ...
# 5477   Cant understand way calculate square number fo...
# 43235  Mapping Java boolean Oracle Number column JPA ...
# 33186  Angular wait subscribe finish updateaccess var...
# 14324  Facebook Graph API GET request Should contain ...
# 42326  What correct format upgrade pip default pip pi...
#
# [9951 rows x 10 columns]

# %%
# Verification nombre unique de tags
len(data["Tags"].explode().unique())
# Out:
# 50

# %% [markdown]
# ### Suppression des tags  ne revennant qu'une seule fois

# %%
# Compte le nombre d'occurrences de chaque classe
tag_counts = data['Tags'].explode().value_counts()

# Identifie les classes avec moins de deux occurrences
problematic_classes = tag_counts[tag_counts < 2].index

# Filtre les lignes de l'ensemble de données pour exclure les classes problématiques
data = data[~data['Tags'].apply(lambda x: any(tag in problematic_classes for tag in x))]
data
# Out:
#              Id                                              Title  \
# 39489  49028212             Precompile asp.net views with ms build
# 10822   2875429  IUnityContainer.Resolve<T> throws error claimi...
# 4144    1235958              IPC performance: Named Pipe vs Socket
# 38695  30525184                    Array vs Slice: accessing speed
# 29282  30386317  Babelify throws ParseError on import a module ...
# ...         ...                                                ...
# 5477   27828822  Can't understand this way to calculate the squ...
# 43235  28865222  Mapping Java boolean to Oracle Number column w...
# 33186  50951779  Angular 2+ wait for subscribe to finish to upd...
# 14324  32031677  Facebook Graph API GET request - Should contai...
# 42326  39129450  What is the correct format to upgrade pip3 whe...
#
#                                                     Body  \
# 39489  <p>When I deploy asp.net application through v...
# 10822  <p>Yesterday I've implemented the code:</p>\n\...
# 4144   <p>Everyone seems to say named pipes are faste...
# 38695  <p>This question is about the speed of <em>acc...
# 29282  <p>I'm working with <code>Babelify</code> and ...
# ...                                                  ...
# 5477   <p>I have found a function that calculates squ...
# 43235  <p>I have a property created like this in my m...
# 33186  <p>I am having an issue with my variables bein...
# 14324  <p>My iOS app uses Facebook's Graph API Reques...
# 42326  <p>I develop for both <code>Python 2</code> an...
#
#                                             Tags  Score  ViewCount  \
# 39489  [c#, asp.net, asp.net-mvc, visual-studio]     25      14467
# 10822                                 [c#, .net]     77      40728
# 4144                        [linux, performance]    169     140521
# 38695                      [arrays, performance]     25      10443
# 29282                      [javascript, node.js]     32      19613
# ...                                          ...    ...        ...
# 5477                                 [c, arrays]    135       9480
# 43235                           [java, database]     23      32847
# 33186                      [javascript, angular]     29     106864
# 14324                        [ios, xcode, swift]     60      47952
# 42326                       [python, python-3.x]     23      62360
#
#        FavoriteCount  AnswerCount         CreationDate  \
# 39489            0.0            1  2018-02-28 11:12:01
# 10822            0.0            5  2010-05-20 15:46:20
# 4144             0.0           12  2009-08-05 21:52:24
# 38695            0.0            3  2015-05-29 08:49:35
# 29282            0.0            3  2015-05-21 23:58:19
# ...              ...          ...                  ...
# 5477             0.0            5  2015-01-07 21:18:20
# 43235            0.0            2  2015-03-04 21:21:35
# 33186            0.0            2  2018-06-20 15:23:12
# 14324            0.0            5  2015-08-16 03:58:10
# 42326            0.0            2  2016-08-24 17:20:10
#
#                                               Title_Body
# 39489  Precompile aspnet views build When deploy aspn...
# 10822  IUnityContainerResolve throws error claiming c...
# 4144   IPC performance Named Pipe Socket Everyone see...
# 38695  Array Slice accessing speed This question spee...
# 29282  Babelify throws ParseError import module nodem...
# ...                                                  ...
# 5477   Cant understand way calculate square number fo...
# 43235  Mapping Java boolean Oracle Number column JPA ...
# 33186  Angular wait subscribe finish updateaccess var...
# 14324  Facebook Graph API GET request Should contain ...
# 42326  What correct format upgrade pip default pip pi...
#
# [9951 rows x 10 columns]

# %% [markdown]
# # Approche non supervisée

# %% [markdown]
# ### Train test split

# %%
# TfidfVectorizer
from sklearn import model_selection
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV

# Récupération des valeurs
X = data["Title_Body"]

# Découpe du jeu en Train et Test 70 / 30
X_train, X_test = model_selection.train_test_split(X, test_size=0.3, random_state=42)

# Vectorisation
tfidf_vectorizer = TfidfVectorizer(
    max_df=0.95, 
    min_df=2, 
    max_features=limite, 
    stop_words="english")

# Ajustement de tfidf_vectorizer sur les documents
tfidf_data_vectorized = tfidf_vectorizer.fit_transform(X_train)
tfidf_data_test_vectorized = tfidf_vectorizer.transform(X_test)

# Recupération du vocabulaire
vocabulaire = tfidf_vectorizer.vocabulary_

# Paramètres LDA #'n_components': [10, 15, 20], 'learning_decay': [.5, .7, .9]
search_params = {'n_components': [10], 'learning_decay': [.9]} # A remettre plus tard (gain de temps de calcul)

# Initialisation du modèle LDA
lda = LatentDirichletAllocation()

# Initialisation GridSearchCV
model = GridSearchCV(lda, param_grid=search_params)

# Entrainement
model.fit(tfidf_data_vectorized)

# Meilleur modèle
best_lda_model = model.best_estimator_
best_lda_model
# Out:
# LatentDirichletAllocation(learning_decay=0.9)

# %%
# Mesure des performances du modele

# Score de log-vraisemblance: plus c'est élévé mieux c'est
print("Log Likelihood: ", best_lda_model.score(tfidf_data_vectorized))

# Mesure de l'incertitude du modèle: plus c'est bas mieux c'est, cela suggère une meilleure capacité à prédire les données par le modèle
print("Perplexité: ", best_lda_model.perplexity(tfidf_data_vectorized))

print(best_lda_model.get_params())
# Out:
# Log Likelihood:  -356520.86871039117
# Perplexité:  27294.244995604375
# {'batch_size': 128, 'doc_topic_prior': None, 'evaluate_every': -1, 'learning_decay': 0.9, 'learning_method': 'batch', 'learning_offset': 10.0, 'max_doc_update_iter': 100, 'max_iter': 10, 'mean_change_tol': 0.001, 'n_components': 10, 'n_jobs': None, 'perp_tol': 0.1, 'random_state': None, 'topic_word_prior': None, 'total_samples': 1000000.0, 'verbose': 0}

# %%
import pyLDAvis
import pyLDAvis.lda_model

pyLDAvis.enable_notebook()
panel = pyLDAvis.lda_model.prepare(best_lda_model, tfidf_data_vectorized, tfidf_vectorizer)
panel
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 4     -0.262217  0.079756       1        1  44.534466
# 9     -0.232782 -0.089019       2        1  31.153583
# 3      0.010224  0.007039       3        1   4.364550
# 8      0.067977 -0.025922       4        1   3.342614
# 1      0.071686 -0.006806       5        1   3.078162
# 7      0.070911  0.002343       6        1   2.916747
# 5      0.072629  0.007177       7        1   2.840079
# 6      0.071526  0.005742       8        1   2.827353
# 2      0.068888  0.008689       9        1   2.608920
# 0      0.061159  0.011001      10        1   2.333527, topic_info=            Term       Freq      Total Category  logprob  loglift
# 3602         div  53.000000  53.000000  Default  30.0000  30.0000
# 5977      import  53.000000  53.000000  Default  29.0000  29.0000
# 4603        file  97.000000  97.000000  Default  28.0000  28.0000
# 13857       view  46.000000  46.000000  Default  27.0000  27.0000
# 5922       image  47.000000  47.000000  Default  26.0000  26.0000
# ...          ...        ...        ...      ...      ...      ...
# 1500     bundler   0.635263   1.884619  Topic10  -7.1563   2.6703
# 13274    uicolor   0.896168   3.597127  Topic10  -6.8122   2.3680
# 12025  stopwatch   0.648005   2.148507  Topic10  -7.1364   2.5592
# 9961      quotes   0.589133   3.659882  Topic10  -7.2317   1.9313
# 5344     groupby   0.523685   2.427392  Topic10  -7.3494   2.2241
#
# [562 rows x 6 columns], token_table=       Topic      Freq        Term
# term
# 193        5  0.945617    addrline
# 203        5  0.886386    adecoder
# 209       10  0.902268  adipiscing
# 285       10  0.891353         aib
# 308        8  0.894507     alength
# ...      ...       ...         ...
# 14324      2  0.956003       xcode
# 14406      9  0.953965         xss
# 14411      7  0.646771       xunit
# 14448      1  0.324998     youtube
# 14448      4  0.324998     youtube
#
# [764 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[5, 10, 4, 9, 2, 8, 6, 7, 3, 1])

# %%
# https://openclassrooms.com/fr/courses/4470541-analysez-vos-donnees-textuelles/4855011-modelisez-des-sujets-avec-des-methodes-non-supervisees

# Fonction qui affiche les mots qui ont le plus de poids (termes)
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic {}:".format(topic_idx))
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

# Affiche les 10 mots les plus représentatifs de la catégorie qui a été détectée
display_topics(best_lda_model, tfidf_vectorizer.get_feature_names_out(), 10)
# Out:
# Topic 0:
# using file error string code use public like class new
# Topic 1:
# nan sed dog whitespace accesscontrolalloworigin animal nextjs pandas browserify cors
# Topic 2:
# table column select sql pandas dataframe date rows query row
# Topic 3:
# div image button view ios color css width height html
# Topic 4:
# ptr mov eax rax directives nsnotificationcenter faviconico literals recognition reactscripts

# %%
# Enregistrement du vocabulaire dans un dictionnaire (enregistrement des mots unique)
vocabulaire = tfidf_vectorizer.vocabulary_
vocabulaire
# Out:
# {'bootstrap': 1320,
#  'throws': 12848,
#  'uncaught': 13375,
#  'error': 4172,
#  'bootstraps': 1322,
#  'javascript': 6600,
#  'requires': 10512,
#  'jquery': 6707,
#  'trying': 13151,
#  'use': 13591,
#  'make': 7383,
#  'interface': 6331,
#  'program': 9693,
#  'added': 160,
#  'head': 5491,
#  'tag': 12522,
#  'thought': 12819,
#  'launch': 6929,
#  'web': 14009,
#  'page': 8939,
#  'browser': 1418,
#  'reports': 10417,
#  'tried': 13110,
#  'using': 13670,
#  'copies': 2663,
#  'hosted': 5650,
#  'cdns': 1690,
#  'work': 14228,
#  'anybody': 516,
#  'point': 9359,
#  'wrong': 14279,
#  'mimic': 7696,
#  'keyboard': 6815,
#  'animation': 488,
#  'ios': 6441,
#  'add': 159,
#  'button': 1511,
#  'numeric': 8521,
#  'like': 7061,
#  'older': 8639,
#  'version': 13829,
#  'cgrect': 1759,
#  'cgrectmake': 1760,
#  'uiapplication': 13264,
#  'sharedapplication': 11322,
#  'windows': 14158,
#  'lastobject': 6918,
#  'cgpoint': 1756,
#  'uiview': 13341,
#  'floatvalue': 4766,
#  'delay': 3252,
#  'intvalue': 6398,
#  'animations': 489,
#  'completionnil': 2283,
#  'stopped': 12021,
#  'working': 14238,
#  'values': 13757,
#  'returned': 10674,
#  'longer': 7251,
#  'exactly': 4275,
#  'correct': 2690,
#  'display': 3566,
#  'aggregate': 271,
#  'value': 13740,
#  'introduced': 6387,
#  'django': 3615,
#  'query': 9926,
#  'count': 2715,
#  'number': 8514,
#  'times': 12890,
#  'player': 9315,
#  'played': 9314,
#  'week': 14077,
#  'complains': 2270,
#  'fielderror': 4592,
#  'resolve': 10556,
#  'keyword': 6836,
#  'field': 4591,
#  'choices': 1832,
#  'lists': 7130,
#  'model': 7798,
#  'fields': 4593,
#  'raw': 10015,
#  'sql': 11752,
#  'select': 11097,
#  'group': 5343,
#  'good': 5264,
#  'way': 13999,
#  'executing': 4327,
#  'python': 9894,
#  'string': 12072,
#  'html': 5685,
#  'jupyter': 6777,
#  'notebook': 8384,
#  'ipython': 6463,
#  'used': 13595,
#  'able': 22,
#  'contains': 2549,
#  'actual': 145,
#  'function': 5020,
#  'ipythons': 6465,
#  'module': 7839,
#  'import': 5977,
#  'exists': 4344,
#  'does': 3683,
#  'know': 6865,
#  'bit': 1230,
#  'kill': 6846,
#  'child': 1822,
#  'processes': 9659,
#  'parent': 9011,
#  'dies': 3462,
#  'process': 9654,
#  'started': 11848,
#  'ensure': 4097,
#  'killed': 6847,
#  'terminates': 12658,
#  'abnormally': 23,
#  'need': 8193,
#  'linux': 7099,
#  'aware': 996,
#  'solution': 11594,
#  'edit': 3887,
#  'requirement': 10504,
#  'starting': 11851,
#  'different': 3467,
#  'method': 7649,
#  'combine': 2182,
#  'minify': 7711,
#  'multiple': 7951,
#  'css': 2852,
#  'files': 4627,
#  'optimize': 8763,
#  'site': 11480,
#  'performance': 9138,
#  'compressing': 2321,
#  'question': 9936,
#  'concrete': 2359,
#  'steps': 12006,
#  'achieve': 96,
#  'given': 5220,
#  'real': 10092,
#  'situation': 11486,
#  'facing': 4467,
#  'typical': 13239,
#  'developers': 3403,
#  'references': 10236,
#  'following': 4801,
#  'easier': 3856,
#  'smaller': 11551,
#  'development': 3405,
#  'link': 7085,
#  'typetextcss': 13236,
#  'relstylesheet': 10332,
#  'script': 11011,
#  'typetextjavascript': 13237,
#  'production': 9679,
#  'release': 10315,
#  'compressor': 2324,
#  'update': 13521,
#  'pages': 8948,
#  'needs': 8198,
#  'reference': 10233,
#  'errorprone': 4193,
#  'youre': 14447,
#  'removing': 10362,
#  'adding': 170,
#  'lines': 7084,
#  'approach': 622,
#  'issue': 6501,
#  'rails': 9974,
#  'users': 13649,
#  'seen': 11086,
#  'time': 12875,
#  'devise': 3413,
#  'stores': 12035,
#  'datetimes': 3083,
#  'lets': 7004,
#  'say': 10932,
#  'user': 13605,
#  'logged': 7219,
#  'month': 7876,
#  'ago': 278,
#  'viewed': 13872,
#  'minutes': 7730,
#  'problems': 9645,
#  'creating': 2794,
#  'foreignkey': 4857,
#  'relationship': 10307,
#  'entity': 4111,
#  'framework': 4947,
#  'trouble': 13125,
#  'configuring': 2402,
#  'foreign': 4856,
#  'key': 6814,
#  'fluent': 4770,
#  'api': 529,
#  'report': 10413,
#  'public': 9816,
#  'class': 1887,
#  'details': 3385,
#  'new': 8232,
#  'virtual': 13906,
#  'int': 6277,
#  'idtest': 5859,
#  'set': 11251,
#  'byte': 1524,
#  'blob': 1264,
#  'testtable': 12703,
#  'definition': 3241,
#  'primary': 9581,
#  'isrequired': 6499,
#  'table': 12497,
#  'column': 2164,
#  'mappings': 7443,
#  'properties': 9740,
#  'relationships': 10308,
#  'withmanyt': 14191,
#  'execution': 4328,
#  'conflicts': 2413,
#  'referential': 10238,
#  'constraint': 2515,
#  'role': 10743,
#  'dependent': 3313,
#  'nonnullable': 8342,
#  'principal': 9589,
#  'guess': 5369,
#  'means': 7567,
#  'failing': 4487,
#  'dont': 3704,
#  'really': 10102,
#  'look': 7257,
#  'appreciated': 621,
#  'installing': 6249,
#  'pandas': 8969,
#  'docker': 3658,
#  'alpine': 372,
#  'hard': 5448,
#  'install': 6242,
#  'stable': 11805,
#  'data': 2982,
#  'science': 10978,
#  'package': 8916,
#  'configuration': 2390,
#  'mainstream': 7364,
#  'relevant': 10320,
#  'tools': 12973,
#  'dockerfile': 3661,
#  'hack': 5399,
#  'core': 2673,
#  'separately': 11180,
#  'specifying': 11689,
#  'allegedly': 345,
#  'higher': 5573,
#  'versions': 13836,
#  'conflict': 2410,
#  'numpy': 8524,
#  'env': 4133,
#  'packages': 8922,
#  'musl': 7970,
#  'bash': 1098,
#  'git': 5215,
#  'freetype': 4967,
#  'libgcc': 7028,
#  'libstdc': 7043,
#  'tcl': 12587,
#  'matplotlib': 7516,
#  'scipy': 10981,
#  'scikitlearn': 10980,
#  'nltk': 8291,
#  'run': 10834,
#  'apk': 540,
#  'nocache': 8295,
#  'pythondev': 9896,
#  'pkgconfig': 9283,
#  'gfortran': 5202,
#  'pip': 9266,
#  'upgrade': 13531,
#  'setuptools': 11298,
#  'usrbinpython': 13679,
#  'usrbinpip': 13678,
#  'del': 3250,
#  'directory': 3498,
#  'workdir': 14233,
#  'requirements': 10505,
#  'copy': 2664,
#  'requirementstxt': 10506,
#  'chmod': 1830,
#  'app': 545,
#  'server': 11216,
#  'cmd': 2065,
#  'happens': 5445,
#  'build': 1468,
#  'fails': 4488,
#  'importerror': 5982,
#  'missing': 7743,
#  'required': 10489,
#  'dependencies': 3307,
#  'installed': 6245,
#  'anymore': 517,
#  'obtain': 8585,
#  'note': 8383,
#  'consisting': 2472,
#  'pull': 9838,
#  'image': 5922,
#  'mentioned': 7610,
#  'welcomed': 14089,
#  'suggested': 12273,
#  'comments': 2213,
#  'breaks': 1389,
#  'complaining': 2269,
#  'collecting': 2133,
#  'line': 7073,
#  'downloading': 3732,
#  'complete': 2274,
#  'output': 8857,
#  'command': 2196,
#  'setuppy': 11295,
#  'egginfo': 3917,
#  'traceback': 13009,
#  'recent': 10132,
#  'file': 4603,
#  'keyerror': 6819,
#  'handling': 5434,
#  'exception': 4292,
#  'occurred': 8600,
#  'resourcefilename': 10567,
#  'return': 10673,
#  'modulenotfounderror': 7845,
#  'named': 8090,
#  'failed': 4485,
#  'code': 2090,
#  'open': 8706,
#  'refer': 10232,
#  'github': 5216,
#  'unfortunately': 13409,
#  'insufficient': 6275,
#  'setting': 11288,
#  'environment': 4134,
#  'container': 2543,
#  'important': 5979,
#  'read': 10065,
#  'advice': 246,
#  'solve': 11596,
#  'importing': 5984,
#  'extension': 4433,
#  'likely': 7063,
#  'proceed': 9650,
#  'repository': 10421,
#  'try': 13146,
#  'clean': 1982,
#  'xdf': 14340,
#  'removes': 10361,
#  'control': 2614,
#  'rebuild': 10117,
#  'simply': 11457,
#  'installation': 6243,
#  'broken': 1412,
#  'reinstall': 10288,
#  'reinstalled': 10289,
#  'fix': 4715,
#  'problem': 9643,
#  'check': 1804,
#  'expect': 4360,
#  'usrlocalbinpython': 13690,
#  'directories': 3497,
#  'path': 9063,
#  'pythonpath': 9900,
#  'interfere': 6334,
#  'looks': 7260,
#  'fine': 4680,
#  'include': 6022,
#  'operating': 8735,
#  'built': 1484,
#  'source': 11636,
#  'compiler': 2261,
#  'ideally': 5814,
#  'log': 7212,
#  'accepted': 52,
#  'building': 1475,
#  'scipys': 10982,
#  'wheel': 14104,
#  'running': 10844,
#  'errored': 4178,
#  'exit': 4345,
#  'status': 11898,
#  'sys': 12423,
#  'tokenize': 12952,
#  'sysargv': 12425,
#  'nfcloseexeccompilecode': 8259,
#  'exec': 4315,
#  'cwd': 2946,
#  'supported': 12322,
#  'instead': 6265,
#  'cleans': 1989,
#  'versioned': 13831,
#  'doesnt': 3684,
#  'touch': 12997,
#  'arent': 673,
#  'checked': 1807,
#  'repo': 10412,
#  'force': 4843,
#  'unsupported': 13505,
#  'cleaning': 1986,
#  'dir': 3488,
#  'successfully': 12252,
#  'wheels': 14105,
#  'pep': 9127,
#  'directly': 3495,
#  'current': 2899,
#  'difference': 3465,
#  'lowerbound': 7289,
#  'includes': 6030,
#  'algorithm': 326,
#  'cases': 1642,
#  'gives': 5221,
#  'answer': 508,
#  'convenient': 2626,
#  'parameter': 9000,
#  'did': 3452,
#  'miss': 7740,
#  'functions': 5052,
#  'thing': 12775,
#  'design': 3354,
#  'lib': 7017,
#  'silly': 11435,
#  'didnt': 3454,
#  'understand': 13395,
#  'create': 2772,
#  'layout': 6942,
#  'blue': 1277,
#  'area': 671,
#  'parallax': 8988,
#  'scroll': 11017,
#  'gridview': 5339,
#  'grid': 5334,
#  'view': 13857,
#  'appbarlayout': 549,
#  'works': 14242,
#  'recyclerview': 10184,
#  'xml': 14378,
#  'encodingutf': 4037,
#  'androidididappbar': 431,
#  'androidbackground': 427,
#  'imageview': 5941,
#  'androidlayoutwidthdp': 438,
#  'androidlayoutheightdp': 435,
#  'androidididtoolbar': 432,
#  'applayoutcollapsemodepin': 579,
#  'androidclickabletrue': 428,
#  'help': 5527,
#  'socketio': 11582,
#  'referenceerror': 10235,
#  'defined': 3234,
#  'writing': 14276,
#  'application': 587,
#  'android': 424,
#  'compatible': 2252,
#  'wish': 14184,
#  'transfer': 13041,
#  'apps': 641,
#  'htmljavascript': 5696,
#  'uses': 13662,
#  'engine': 4077,
#  'retrieve': 10662,
#  'ive': 6555,
#  'things': 12776,
#  'looked': 7258,
#  'various': 13784,
#  'forums': 4923,
#  'answers': 511,
#  'tutorials': 13180,
#  'heres': 5539,
#  'indexhtml': 6076,
#  'charsetutf': 1795,
#  'var': 13768,
#  'socket': 11581,
#  'functiondata': 5028,
#  'msg': 7921,
#  'send': 11160,
#  'catcherr': 1659,
#  'alerterror': 313,
#  'encountered': 4041,
#  'err': 4163,
#  'end': 4051,
#  'tell': 12620,
#  'pretty': 9563,
#  'confused': 2417,
#  'test': 12668,
#  'keeps': 6807,
#  'coming': 2194,
#  'sites': 11483,
#  'requiresocketio': 10513,
#  'results': 10643,
#  'require': 10483,
#  'folder': 4794,
#  'makes': 7391,
#  'sense': 11170,
#  'imply': 5976,
#  'nodejs': 8304,
#  'reply': 10411,
#  'edits': 3895,
#  'chrome': 1845,
#  'giving': 5222,
#  'socketiojs': 11583,
#  'decide': 3159,
#  'requirejs': 10503,
#  'right': 10723,
#  'loaded': 7158,
#  'context': 2582,
#  'care': 1624,
#  'connection': 2430,
#  'define': 3233,
#  'website': 14065,
#  'argument': 685,
#  'occurs': 8604,
#  'typeerror': 13210,
#  'undefined': 13387,
#  'remove': 10355,
#  'special': 11674,
#  'characters': 1786,
#  'space': 11650,
#  'huge': 5767,
#  'corpus': 2688,
#  'text': 12707,
#  'want': 13969,
#  'sustain': 12359,
#  'structure': 12119,
#  'hello': 5523,
#  'world': 14245,
#  'welcome': 14088,
#  'million': 7690,
#  'followed': 4800,
#  'virtualenv': 13908,
#  'mysql': 8042,
#  'bindings': 1217,
#  'prefer': 9496,
#  'easyinstall': 3862,
#  'mysqlconfig': 8044,
#  'raise': 9978,
#  'gets': 5186,
#  'similar': 11439,
#  'google': 5266,
#  'cloud': 2043,
#  'increasing': 6052,
#  'size': 11490,
#  'disk': 3548,
#  'reason': 10108,
#  'explain': 4388,
#  'second': 11055,
#  'edition': 3891,
#  'databases': 2991,
#  'total': 12990,
#  'storage': 12029,
#  'usage': 13584,
#  'going': 5258,
#  'faster': 4521,
#  'export': 4407,
#  'bucket': 1449,
#  'created': 2776,
#  'instance': 6253,
#  'delete': 3260,
#  'changed': 1774,
#  'applications': 601,
#  'sure': 12337,
#  'come': 2188,
#  'overhead': 8875,
#  'binary': 1205,
#  'logs': 7246,
#  'think': 12778,
#  'purge': 9851,
#  'easy': 3861,
#  'final': 4655,
#  'active': 130,
#  'expand': 4354,
#  'continuously': 2602,
#  'uncheck': 13378,
#  'sorry': 11622,
#  'noob': 8361,
#  'beginner': 1146,
#  'administration': 221,
#  'thanks': 12746,
#  'adjust': 213,
#  'uibarbuttonitem': 13268,
#  'rightbarbuttonitems': 10724,
#  'codes': 2106,
#  'buttons': 1516,
#  'wide': 14117,
#  'decrease': 3195,
#  'alloc': 347,
#  'initwithimageuiimage': 6171,
#  'targetself': 12555,
#  'nsarray': 8424,
#  'arr': 703,
#  'appreciate': 620,
#  'hint': 5584,
#  'idea': 5812,
#  'possible': 9429,
#  'declare': 3172,
#  'variable': 13774,
#  'gradle': 5295,
#  'usable': 13583,
#  'java': 6579,
#  'basically': 1102,
#  'buildgradle': 1474,
#  'getting': 5196,
#  'obviously': 8589,
#  'just': 6778,
#  'preprocessor': 9530,
#  'macros': 7326,
#  'example': 4280,
#  'declaration': 3168,
#  'debug': 3148,
#  'fixed': 4716,
#  'buffers': 1460,
#  'arrays': 726,
#  'declared': 3173,
#  'unsafe': 13492,
#  'type': 13198,
#  'bytes': 1532,
#  'struct': 12116,
#  'buffer': 1454,
#  'simpler': 11447,
#  'course': 2731,
#  'lies': 7051,
#  'provided': 9779,
#  'implemented': 5967,
#  'pointers': 9366,
#  'provide': 9777,
#  'arbitrary': 661,
#  'constant': 2505,
#  'length': 6994,
#  'making': 7393,
#  'array': 707,
#  'changing': 1779,
#  'locale': 7174,
#  'preferred': 9504,
#  'encoding': 4034,
#  'recently': 10133,
#  'switched': 12388,
#  'usually': 13696,
#  'runs': 10847,
#  'according': 80,
#  'documentation': 3670,
#  'default': 3211,
#  'arg': 675,
#  'supplied': 12317,
#  'utf': 13699,
#  'project': 9712,
#  'matter': 7521,
#  'currently': 2906,
#  'calls': 1574,
#  'change': 1773,
#  'locales': 7175,
#  'sees': 11087,
#  'previous': 9574,
#  'commands': 2204,
#  'comment': 2209,
#  'specifically': 11680,
#  'suggest': 12272,
#  'transcript': 13040,
#  'window': 14141,
#  'opened': 8712,
#  'intended': 6297,
#  'transmit': 13069,
#  'password': 9052,
#  'dialog': 3441,
#  'modal': 7789,
#  'box': 1362,
#  'pop': 9391,
#  'logging': 7224,
#  'clicks': 2008,
#  'login': 7231,
#  'post': 9431,
#  'request': 10442,
#  'follows': 4802,
#  'username': 13637,
#  'pass': 9044,
#  'json': 6728,
#  'putting': 9864,
#  'passwords': 9054,
#  'stored': 12032,
#  'database': 2985,
#  'compare': 2242,
#  'submitted': 12200,
#  'replies': 10410,
#  'sdkmanager': 11032,
#  'list': 7106,
#  'downloaded': 3730,
#  'jdk': 6642,
#  'oracle': 8780,
#  'sdk': 11031,
#  'replaced': 10401,
#  'managing': 7409,
#  'components': 2304,
#  'shown': 11377,
#  'thread': 12823,
#  'main': 7344,
#  'caused': 1672,
#  'javatm': 6612,
#  'runtime': 10851,
#  'hotspottm': 5658,
#  'mixed': 7753,
#  'mode': 7795,
#  'related': 10301,
#  'questions': 9938,
#  'androidsdk': 445,
#  'asked': 765,
#  'closed': 2035,
#  'suggests': 12277,
#  'warning': 13977,
#  'sidebyside': 11394,
#  'wanted': 13970,
#  'cpu': 2750,
#  'cache': 1539,
#  'flush': 4773,
#  'interested': 6328,
#  'forcing': 4849,
#  'benchmarking': 1170,
#  'reasons': 10112,
#  'emulate': 4002,
#  'preferably': 9498,
#  'basic': 1101,
#  'implementation': 5964,
#  'win': 14139,
#  'known': 6868,
#  'sneaky': 11569,
#  'large': 6909,
#  'memcpy': 7600,
#  'intel': 6290,
#  'platform': 9308,
#  'okay': 8634,
#  'determine': 3392,
#  'nsdate': 8430,
#  'today': 12940,
#  'belongs': 1164,
#  'adate': 157,
#  'description': 3341,
#  'substringtoindex': 12234,
#  'returns': 10676,
#  'yyyymmdd': 14454,
#  'compared': 2243,
#  'date': 3055,
#  'fast': 4519,
#  'andor': 422,
#  'neat': 8187,
#  'whats': 14102,
#  'lowlevel': 7292,
#  'corresponding': 2701,
#  'crt': 2831,
#  'completely': 2276,
#  'stack': 11806,
#  'frame': 4941,
#  'distinction': 3591,
#  'caught': 1670,
#  'runtimeexception': 10853,
#  'binder': 1211,
#  'stub': 12128,
#  'swap': 12366,
#  'arrayadapter': 709,
#  'mainactivity': 7345,
#  'extends': 4431,
#  'appcompatactivity': 552,
#  'arrayliststring': 723,
#  'arraylist': 719,
#  'arrayadapterstring': 710,
#  'adapter': 153,
#  'override': 8893,
#  'protected': 9763,
#  'void': 13934,
#  'oncreatebundle': 8663,
#  'savedinstancestate': 10923,
#  'private': 9632,
#  'boolean': 1304,
#  'oncreateoptionsmenumenu': 8664,
#  'menu': 7613,
#  'inflate': 6113,
#  'adds': 194,
#  'items': 6518,
#  'action': 111,
#  'bar': 1070,
#  'present': 9537,
#  'true': 13133,
#  'item': 6512,
#  'handle': 5424,
#  'automatically': 944,
#  'homeup': 5621,
#  'long': 7250,
#  'specify': 11688,
#  'activity': 139,
#  'androidmanifestxml': 440,
#  'itemgetitemid': 6514,
#  'noinspection': 8314,
#  'simplifiableifstatement': 11450,
#  'ddalvikvm': 3124,
#  'freed': 4959,
#  'free': 4957,
#  'paused': 9079,
#  'appears': 566,
#  'randomly': 9991,
#  'click': 2003,
#  'stdarray': 11910,
#  'guarantee': 5362,
#  'allocation': 352,
#  'stdarrayint': 11911,
#  'guaranteed': 5363,
#  'allocated': 349,
#  'heap': 5505,
#  'clear': 1993,
#  'mean': 7562,
#  'mainly': 7356,
#  'wonder': 14216,
#  'standard': 11831,
#  'library': 7037,
#  'allowed': 358,
#  'inside': 6229,
#  'xcode': 14324,
#  'considering': 2467,
#  'features': 4545,
#  'auto': 920,
#  'crossplatform': 2830,
#  'projects': 9718,
#  'visual': 13924,
#  'studio': 12136,
#  'supports': 12325,
#  'parts': 9040,
#  'upcoming': 13519,
#  'allow': 356,
#  'simplify': 11454,
#  'base': 1079,
#  'naturally': 8154,
#  'far': 4515,
#  'gcc': 5098,
#  'support': 12320,
#  'clang': 1880,
#  'bite': 1233,
#  'wait': 13955,
#  'apple': 580,
#  'future': 5069,
#  'bind': 1208,
#  'visibility': 13914,
#  'property': 9741,
#  'border': 1324,
#  'label': 6878,
#  'borderthickness': 1331,
#  'horizontalalignmentleft': 5642,
#  'height': 5515,
#  'margin': 7454,
#  'verticalalignmenttop': 13845,
#  'width': 14123,
#  'opacity': 8703,
#  'bool': 1303,
#  'vis': 13913,
#  'false': 4502,
#  'ruby': 10824,
#  'gems': 5115,
#  'rvm': 10862,
#  'libraries': 7036,
#  'setups': 11296,
#  'technologies': 12613,
#  'began': 1142,
#  'rubygems': 10825,
#  'tutorial': 13179,
#  'download': 3728,
#  'tar': 12545,
#  'talking': 12537,
#  'unnecessary': 13472,
#  'actually': 148,
#  'precise': 9479,
#  'equality': 4146,
#  'inconsistency': 6040,
#  'consider': 2461,
#  'mytype': 8069,
#  'static': 11874,
#  'mainstring': 7365,
#  'args': 680,
#  'typeofstring': 13222,
#  'equals': 4149,
#  'equalitycomparerdefault': 4147,
#  'probably': 9641,
#  'objectequals': 8554,
#  'match': 7493,
#  'inconsistent': 6041,
#  'normal': 8368,
#  'creates': 2788,
#  'inherits': 6134,
#  'imagine': 5945,
#  'placing': 9298,
#  'types': 13228,
#  'keys': 6826,
#  'dictionary': 3450,
#  'comparisons': 2249,
#  'methods': 7656,
#  'textalign': 12708,
#  'safari': 10874,
#  'aligning': 336,
#  'element': 3934,
#  'center': 1708,
#  'worked': 14234,
#  'textaligncenter': 12709,
#  'browsers': 1424,
#  'align': 333,
#  'left': 6980,
#  'webkitappearance': 14030,
#  'fixtures': 4726,
#  'loading': 7164,
#  'rspec': 10815,
#  'learn': 6969,
#  'bdd': 1118,
#  'testing': 12689,
#  'life': 7052,
#  'load': 7154,
#  'properly': 9739,
#  'descriptions': 3343,
#  'disclaimer': 3527,
#  'yes': 14435,
#  'better': 1181,
#  'play': 9312,
#  'associated': 821,
#  'factorygirl': 4477,
#  'mocha': 7777,
#  'clunky': 2052,
#  'secret': 11060,
#  'foo': 4818,
#  'email': 3960,
#  'render': 10368,
#  'index': 6067,
#  'template': 12627,
#  'rake': 9984,
#  'spec': 11672,
#  'nomethoderror': 8321,
#  'methodmissing': 7651,
#  'recognizing': 10146,
#  'valid': 13723,
#  'verify': 13825,
#  'feel': 4557,
#  'obvious': 8588,
#  'tearing': 12607,
#  'hair': 5406,
#  'day': 3090,
#  'avail': 966,
#  'jackson': 6558,
#  'objectmapper': 8560,
#  'spring': 11728,
#  'instantiates': 6260,
#  'autowire': 960,
#  'controllers': 2620,
#  'controller': 2616,
#  'minor': 7724,
#  'parsing': 9028,
#  'accomplishing': 78,
#  'asking': 766,
#  'custom': 2919,
#  'configure': 2393,
#  'happy': 5447,
#  'defaults': 3222,
#  'fish': 4710,
#  'reuse': 10682,
#  'existing': 4343,
#  'sync': 12405,
#  'cause': 1671,
#  'opening': 8719,
#  'zip': 14466,
#  'corrupt': 2703,
#  'dependency': 3308,
#  'learning': 6971,
#  'online': 8681,
#  'developing': 3404,
#  'keeping': 6806,
#  'message': 7626,
#  'displayed': 3567,
#  'event': 4241,
#  'warn': 13976,
#  'direction': 3491,
#  'unable': 13361,
#  'connect': 2427,
#  'postgres': 9443,
#  'authentication': 903,
#  'hands': 5435,
#  'local': 7171,
#  'postgresql': 9444,
#  'maven': 7525,
#  'jpa': 6696,
#  'configured': 2396,
#  'pghbaconf': 9203,
#  'clients': 2017,
#  'address': 186,
#  'subnet': 12203,
#  'scheme': 10972,
#  'driver': 3776,
#  'postgresqljar': 9445,
#  'jdbctemplate': 6641,
#  'modified': 7832,
#  'referring': 10240,
#  'deprecated': 3323,
#  'config': 2380,
#  'datasourceconfig': 3035,
#  'bean': 1120,
#  'drivermanagerdatasource': 3778,
#  'component': 2297,
#  ...}

# %%
# Enregistrement des termes (mots) dans l'ordre
termes_ord = [terme for terme, indice in sorted(vocabulaire.items(), key=lambda x: x[1])]
termes_ord
# Out:
# ['aaa',
#  'aaaa',
#  'aabb',
#  'aac',
#  'aactive',
#  'aad',
#  'aae',
#  'aaf',
#  'aapt',
#  'aaron',
#  'abab',
#  'abandoned',
#  'abc',
#  'abcc',
#  'abcd',
#  'abcdef',
#  'abcdefgh',
#  'abcdefghijklmnop',
#  'abe',
#  'abi',
#  'abilities',
#  'ability',
#  'able',
#  'abnormally',
#  'abort',
#  'aborted',
#  'aborting',
#  'abortonerror',
#  'abovementioned',
#  'abrupt',
#  'abruptly',
#  'abs',
#  'absence',
#  'absolute',
#  'absoluteimport',
#  'absolutely',
#  'abstract',
#  'abstractbaseuser',
#  'abstractcontrol',
#  'abstractfalse',
#  'abstraction',
#  'absurd',
#  'absurdly',
#  'abuse',
#  'academic',
#  'acc',
#  'accelerated',
#  'acceleration',
#  'accents',
#  'accept',
#  'acceptable',
#  'acceptance',
#  'accepted',
#  'acceptencoding',
#  'accepting',
#  'acceptlanguage',
#  'accepts',
#  'access',
#  'accesscontrolallowheaders',
#  'accesscontrolallowmethods',
#  'accesscontrolalloworigin',
#  'accessed',
#  'accesses',
#  'accessibility',
#  'accessible',
#  'accessing',
#  'accesslog',
#  'accessor',
#  'accessors',
#  'accesstoken',
#  'accesstokenexpiretimespan',
#  'accident',
#  'accidental',
#  'accidentally',
#  'accommodate',
#  'accompanying',
#  'accomplish',
#  'accomplished',
#  'accomplishing',
#  'accordance',
#  'according',
#  'accordingly',
#  'accordion',
#  'account',
#  'accountcontroller',
#  'accountid',
#  'accounting',
#  'accountlogin',
#  'accounts',
#  'accross',
#  'accuracy',
#  'accurate',
#  'accurately',
#  'accustomed',
#  'ace',
#  'acf',
#  'achieve',
#  'achieved',
#  'achieves',
#  'achieving',
#  'ack',
#  'acl',
#  'aclass',
#  'aconst',
#  'acos',
#  'acpp',
#  'acquire',
#  'acquired',
#  'acquisition',
#  'act',
#  'acting',
#  'action',
#  'actionbar',
#  'actionbarsherlock',
#  'actioncable',
#  'actioncontrollerbase',
#  'actionfilter',
#  'actionfilterattribute',
#  'actionindex',
#  'actionlink',
#  'actionpack',
#  'actionpayload',
#  'actionresult',
#  'actions',
#  'actiontype',
#  'activate',
#  'activated',
#  'activatedroute',
#  'activating',
#  'activation',
#  'active',
#  'actively',
#  'activemodel',
#  'activerecord',
#  'activerecordbase',
#  'activerecordmigration',
#  'activesupport',
#  'activex',
#  'activities',
#  'activity',
#  'activityfragment',
#  'actor',
#  'actorid',
#  'actors',
#  'acts',
#  'actual',
#  'actualadd',
#  'actualimage',
#  'actually',
#  'acyclic',
#  'adam',
#  'adapt',
#  'adapted',
#  'adapter',
#  'adapters',
#  'adapting',
#  'adata',
#  'adate',
#  'adb',
#  'add',
#  'added',
#  'addeddate',
#  'addedit',
#  'addedremoved',
#  'addendum',
#  'addeventlistener',
#  'addexecutable',
#  'addform',
#  'addin',
#  'addindex',
#  'adding',
#  'addint',
#  'addition',
#  'additional',
#  'additionalinfo',
#  'additionally',
#  'additions',
#  'addl',
#  'addlibrary',
#  'addlibrarymylib',
#  'addmigration',
#  'addobserverself',
#  'addon',
#  'addons',
#  'addr',
#  'addremove',
#  'address',
#  'addressable',
#  'addressed',
#  'addresses',
#  'addressid',
#  'addressing',
#  'addressline',
#  'addrline',
#  'adds',
#  'addstring',
#  'addsubview',
#  'addsubviewrefreshcontrol',
#  'addsubviewtableview',
#  'addsubviewview',
#  'addt',
#  'addtargetself',
#  'addx',
#  'adecoder',
#  'adequate',
#  'adequately',
#  'adhere',
#  'adhoc',
#  'adid',
#  'adipiscing',
#  'adj',
#  'adjacency',
#  'adjacent',
#  'adjust',
#  'adjustable',
#  'adjusted',
#  'adjusting',
#  'adjustment',
#  'adjustments',
#  'admin',
#  'adminautodiscover',
#  'administration',
#  'administrative',
#  'administrator',
#  'administrators',
#  'adminpy',
#  'admins',
#  'admit',
#  'admittedly',
#  'admob',
#  'adobe',
#  'adonet',
#  'adopt',
#  'adopted',
#  'adoption',
#  'adress',
#  'ads',
#  'advance',
#  'advanced',
#  'advantage',
#  'advantages',
#  'advantagesdisadvantages',
#  'adverse',
#  'advertise',
#  'advertised',
#  'advertising',
#  'advice',
#  'advices',
#  'advisable',
#  'advise',
#  'advised',
#  'advising',
#  'aero',
#  'aes',
#  'afaik',
#  'affect',
#  'affected',
#  'affecting',
#  'affects',
#  'affinity',
#  'afford',
#  'afhttprequestoperation',
#  'afinet',
#  'afnetworking',
#  'aforementioned',
#  'afraid',
#  'africa',
#  'afterdelay',
#  'age',
#  'agent',
#  'agg',
#  'aggregate',
#  'aggregated',
#  'aggregateexception',
#  'aggregation',
#  'aggregations',
#  'agmcore',
#  'agnostic',
#  'ago',
#  'agree',
#  'agreed',
#  'agreement',
#  'agrees',
#  'ahead',
#  'ahover',
#  'aib',
#  'aid',
#  'aim',
#  'aimed',
#  'aiming',
#  'aint',
#  'aio',
#  'aiohttp',
#  'air',
#  'ajax',
#  'ajaxrequest',
#  'aka',
#  'akka',
#  'ala',
#  'alabama',
#  'alamofire',
#  'alamofirerequestpost',
#  'alarmmanager',
#  'albeit',
#  'album',
#  'albumid',
#  'albumname',
#  'albums',
#  'alength',
#  'alert',
#  'alertcontroller',
#  'alertdata',
#  'alerted',
#  'alerterror',
#  'alerthi',
#  'alertinvalid',
#  'alertresult',
#  'alerts',
#  'alertsuccess',
#  'alerttest',
#  'alertview',
#  'alertviewcontroller',
#  'alex',
#  'algebra',
#  'alghstypjwt',
#  'algo',
#  'algorithm',
#  'algorithms',
#  'ali',
#  'alias',
#  'aliases',
#  'aliasing',
#  'alice',
#  'align',
#  'aligncenter',
#  'aligned',
#  'aligning',
#  'alignitems',
#  'alignment',
#  'aligns',
#  'alike',
#  'aliqua',
#  'aliquip',
#  'alive',
#  'allargsconstructor',
#  'allegedly',
#  'alleviate',
#  'alloc',
#  'allocate',
#  'allocated',
#  'allocates',
#  'allocating',
#  'allocation',
#  'allocations',
#  'allocator',
#  'allocinit',
#  'allow',
#  'allowanonymous',
#  'allowed',
#  'allowedhosts',
#  'allowfullscreeniframe',
#  'allowing',
#  'allownull',
#  'allows',
#  'allprojects',
#  'alongside',
#  'alot',
#  'alpha',
#  'alphabet',
#  'alphabetical',
#  'alphabetically',
#  'alphanumeric',
#  'alpine',
#  'alright',
#  'alt',
#  'alter',
#  'alteration',
#  'altered',
#  'altering',
#  'alternate',
#  'alternating',
#  'alternative',
#  'alternatively',
#  'alternatives',
#  'altf',
#  'altimage',
#  'altnames',
#  'altogether',
#  'amazed',
#  'amazing',
#  'amazon',
#  'amazons',
#  'ambiguity',
#  'ambiguous',
#  'amd',
#  'amend',
#  'amending',
#  'american',
#  'amet',
#  'amounts',
#  'amp',
#  'ampersand',
#  'ampm',
#  'ampps',
#  'anaconda',
#  'analog',
#  'analogous',
#  'analysis',
#  'analytics',
#  'analyze',
#  'analyzed',
#  'analyzer',
#  'analyzers',
#  'analyzing',
#  'ancestor',
#  'ancestorlevel',
#  'ancestortypextype',
#  'anchor',
#  'anchors',
#  'ancient',
#  'anders',
#  'andexpectstatusisok',
#  'andor',
#  'andrew',
#  'android',
#  'androidallowbackuptrue',
#  'androidappactivity',
#  'androidbackground',
#  'androidclickabletrue',
#  'androidexportedtrue',
#  'androidgraphicscolor',
#  'androidididappbar',
#  'androidididtoolbar',
#  'androidios',
#  'androidlabelstringappname',
#  'androidlayoutheightdp',
#  'androidlayoutmarginleftdp',
#  'androidlayoutweight',
#  'androidlayoutwidthdp',
#  'androidmanifest',
#  'androidmanifestxml',
#  'androidminsdkversion',
#  'androidmk',
#  'androidosbundle',
#  'androids',
#  'androidsdk',
#  'androidshaperectangle',
#  'androidsupportvwidget',
#  'androidthemestyleapptheme',
#  'androidversioncode',
#  'androidversionname',
#  'androidviewview',
#  'androidwidgettoast',
#  'androidx',
#  'angeles',
#  'angle',
#  'angular',
#  'angularanimations',
#  'angularcdk',
#  'angularcli',
#  'angularcommon',
#  'angularcompiler',
#  'angularcompilercli',
#  'angularcore',
#  'angularcoretesting',
#  'angulardevkitbuildangular',
#  'angularfire',
#  'angularforms',
#  'angularhttp',
#  'angularjs',
#  'angularjwt',
#  'angularlanguageservice',
#  'angularmaterial',
#  'angularplatformbrowser',
#  'angularrouter',
#  'angularroutertesting',
#  'angulars',
#  'anim',
#  'animal',
#  'animals',
#  'animatable',
#  'animate',
#  'animated',
#  'animatedno',
#  'animatedyes',
#  'animates',
#  'animatewithduration',
#  'animating',
#  'animation',
#  'animations',
#  'annotate',
#  'annotated',
#  'annotating',
#  'annotation',
#  'annotationidannotation',
#  'annotationprocessor',
#  'annotations',
#  'announced',
#  'announcement',
#  'annoyance',
#  'annoying',
#  'annoyingly',
#  'annoys',
#  'anonymous',
#  'anonymousauthentication',
#  'anonymoususer',
#  'ans',
#  'ansi',
#  'answer',
#  'answered',
#  'answering',
#  'answers',
#  'ant',
#  'anticipate',
#  'antipattern',
#  'antmatchers',
#  'anybody',
#  'anymore',
#  'anyobject',
#  'anyones',
#  'anyrequestauthenticated',
#  'anytime',
#  'anyways',
#  'aop',
#  'aot',
#  'aout',
#  'apache',
#  'apaches',
#  'apart',
#  'api',
#  'apiclient',
#  'apicontroller',
#  'apicontrollers',
#  'apijs',
#  'apikey',
#  'apimanager',
#  'apirequestfactory',
#  'apis',
#  'apiservice',
#  'apiurl',
#  'apk',
#  'apm',
#  'apns',
#  'apologies',
#  'apologize',
#  'app',
#  'apparent',
#  'apparently',
#  'appbar',
#  'appbarlayout',
#  'appbundle',
#  'appcmdexe',
#  'appcompatactivity',
#  'appcomponent',
#  'appconfig',
#  'appdata',
#  'appdatabase',
#  'appdelegate',
#  'appdelegateh',
#  'appdelegatem',
#  'appdelegateswift',
#  'appdomain',
#  'appear',
#  'appearance',
#  'appeared',
#  'appearing',
#  'appears',
#  'append',
#  'appended',
#  'appender',
#  'appending',
#  'appends',
#  'appengine',
#  'appexec',
#  'appget',
#  'apphost',
#  'appid',
#  'appjs',
#  'appjsx',
#  'applayoutcollapsemodepin',
#  'apple',
#  'apples',
#  'applescript',
#  'applet',
#  'applewebkit',
#  'applicable',
#  'applicants',
#  'application',
#  'applicationapp',
#  'applicationapplication',
#  'applicationcontext',
#  'applicationcontextxml',
#  'applicationdbcontext',
#  'applicationid',
#  'applicationjava',
#  'applicationjs',
#  'applicationjson',
#  'applicationoctetstream',
#  'applicationpdf',
#  'applicationproperties',
#  'applicationrb',
#  'applications',
#  'applicationsettings',
#  'applicationstart',
#  'applicationuser',
#  'applicationvndmsexcel',
#  'applied',
#  'applies',
#  'applisten',
#  'applistenport',
#  'applistenprocessenvport',
#  'apply',
#  'applying',
#  'applyloadrules',
#  'appmanager',
#  'appmodule',
#  'appmodulets',
#  'appname',
#  'appprops',
#  'apppy',
#  'appreciate',
#  'appreciated',
#  'approach',
#  'approached',
#  'approaches',
#  'approaching',
#  'appropiate',
#  'appropriate',
#  'appropriately',
#  'approute',
#  'approutingmodule',
#  'approval',
#  'approve',
#  'approved',
#  'approx',
#  'approximate',
#  'approximately',
#  'approximation',
#  'approxj',
#  'approxsize',
#  'apprun',
#  'apps',
#  'appserver',
#  'appsettings',
#  'appsettingsjson',
#  'appstart',
#  'appstore',
#  'appuse',
#  'appuseapi',
#  'appusebodyparserjson',
#  'appusecors',
#  'appuseendpointsendpoints',
#  'appuseexpressjson',
#  'appusemvcroutes',
#  'appuser',
#  'apr',
#  'april',
#  'aproach',
#  'apt',
#  'aptget',
#  'arbitrarily',
#  'arbitrary',
#  'arc',
#  'arch',
#  'architect',
#  'architectural',
#  'architecture',
#  'architectures',
#  'archive',
#  'archived',
#  'archiving',
#  'area',
#  'areas',
#  'arent',
#  'arepository',
#  'arg',
#  'argc',
#  'argcchar',
#  'argh',
#  'argparse',
#  'args',
#  'argsparam',
#  'arguably',
#  'argue',
#  'argues',
#  'argument',
#  'argumenterror',
#  'arguments',
#  'argv',
#  'ariahiddentrue',
#  'ariahiddentruespan',
#  'ariahiddentruetimesbutton',
#  'arial',
#  'arise',
#  'arises',
#  'arithmetic',
#  'arkit',
#  'arm',
#  'armeabi',
#  'armv',
#  'armvl',
#  'armvs',
#  'arose',
#  'arr',
#  'arrange',
#  'arranged',
#  'arrangement',
#  'array',
#  'arraya',
#  'arrayadapter',
#  'arrayadapterstring',
#  'arraybuffer',
#  'arrayfinalizeself',
#  'arrayfoo',
#  'arrayforeach',
#  'arrayi',
#  'arrayij',
#  'arraylength',
#  'arraylike',
#  'arraylist',
#  'arraylistdouble',
#  'arraylistinteger',
#  'arraylistpredicate',
#  'arrayliststring',
#  'arraymap',
#  'arrayobject',
#  'arrays',
#  'arraysaslist',
#  'arraysize',
#  'arraysplice',
#  'arraystring',
#  'arraywithcapacity',
#  'arrcopy',
#  'arri',
#  'arrive',
#  'arrived',
#  'arrives',
#  'arrlength',
#  'arround',
#  'arrow',
#  'arrows',
#  'arrs',
#  'arsenal',
#  'art',
#  'article',
#  'articles',
#  'artifact',
#  'artifactidjunitartifactid',
#  'artificial',
#  'artist',
#  'artists',
#  'asc',
#  'ascending',
#  'ascendingno',
#  'ascendingyes',
#  'ascii',
#  'asciibit',
#  'asdf',
#  'asian',
#  'aside',
#  'asihttprequest',
#  'asin',
#  'asis',
#  'asize',
#  'ask',
#  'asked',
#  'asking',
#  'asks',
#  'asm',
#  'asmx',
#  'asn',
#  'asp',
#  'asparallel',
#  'aspbutton',
#  'aspect',
#  'aspectfit',
#  'aspectj',
#  'aspects',
#  'aspgridview',
#  'aspnet',
#  'aspnetc',
#  'aspnetcore',
#  'aspnets',
#  'aspparameter',
#  'asptextbox',
#  'aspupdatepanel',
#  'aspx',
#  'ass',
#  'assembled',
#  'assembler',
#  'assemblies',
#  'assembly',
#  'assemblybinding',
#  'assemblyidentity',
#  'assemblyinfocs',
#  'assemblyname',
#  'assemblys',
#  'assert',
#  'assertareequal',
#  'assertassertequals',
#  'assertequal',
#  'assertfalse',
#  'asserting',
#  'assertion',
#  'assertionerror',
#  'assertions',
#  'asserts',
#  'assertthrows',
#  'asset',
#  'assets',
#  'assign',
#  'assigned',
#  'assigning',
#  'assignment',
#  'assignments',
#  'assigns',
#  'assist',
#  'assistance',
#  'assistant',
#  'assoc',
#  'associate',
#  'associated',
#  'associatedtype',
#  'association',
#  'associations',
#  'associative',
#  'assume',
#  'assumed',
#  'assumes',
#  'assuming',
#  'assumption',
#  'assumptions',
#  'assure',
#  'assured',
#  'ast',
#  'asterisk',
#  'asterisks',
#  'astonishing',
#  'aswell',
#  'async',
#  'asyncasync',
#  'asyncawait',
#  'asynccallback',
#  'asynchronous',
#  'asynchronously',
#  'asyncio',
#  'asynciocoroutine',
#  'asynciogeteventloop',
#  'asynclaunchasync',
#  'asyncstorage',
#  'asynctask',
#  'asynctaskstring',
#  'asynctaskvoid',
#  'atan',
#  'atest',
#  'atindex',
#  'atlas',
#  'atm',
#  'atoi',
#  'atomic',
#  'atomically',
#  'atomiclong',
#  'atomics',
#  'atop',
#  'ats',
#  'att',
#  'attach',
#  'attached',
#  'attaching',
#  'attachment',
#  'attachmentimagenew',
#  'attachmentimagenewimage',
#  'attack',
#  'attacked',
#  'attacker',
#  'attacks',
#  'attempt',
#  'attempted',
#  'attempting',
#  'attempts',
#  'attention',
#  'attr',
#  'attribute',
#  'attributed',
#  'attributedeprecated',
#  'attributeerror',
#  'attributenoinline',
#  'attributepacked',
#  'attributes',
#  'attributesnil',
#  'attrs',
#  'atxt',
#  'audience',
#  'audio',
#  'audiocontext',
#  'aug',
#  'august',
#  'australia',
#  'auth',
#  'authenticate',
#  'authenticated',
#  'authenticaterequest',
#  'authenticating',
#  'authentication',
#  'authenticationbackends',
#  'authenticationmanager',
#  'authenticode',
#  'authguard',
#  'author',
#  'authoritative',
#  'authorities',
#  'authority',
#  'authorization',
#  'authorize',
#  'authorized',
#  'authorizerequests',
#  'authorizeroles',
#  'authors',
#  'authuser',
#  'authusermodel',
#  'auto',
#  'autocomplete',
#  'autocompleteoff',
#  'autocompletion',
#  'autoconfigfalse',
#  'autoconfigtrue',
#  'autodetectfalse',
#  'autodiscover',
#  'autofac',
#  'autofill',
#  'autofilled',
#  'autogenerate',
#  'autogeneratecolumnsfalse',
#  'autogenerated',
#  'autoincrement',
#  'autoincrementing',
#  'autoincrementtrue',
#  'autolayout',
#  'automagically',
#  'automapper',
#  'automate',
#  'automated',
#  'automates',
#  'automatic',
#  'automatically',
#  'automating',
#  'automation',
#  'autoopen',
#  'autoplay',
#  'autoprefixer',
#  'autoproperty',
#  'autorelease',
#  'autoresetevent',
#  'autoresize',
#  'autoresizing',
#  'autoresizingmask',
#  'autoscroll',
#  'autosize',
#  'autoupdate',
#  'autowatch',
#  'autowire',
#  'autowirecandidatetrue',
#  'autowired',
#  'autowiremode',
#  'autowiring',
#  'auxiliary',
#  'avail',
#  'availability',
#  'available',
#  'availableios',
#  'aval',
#  'avasset',
#  'avassetreader',
#  'avassettrack',
#  'avenues',
#  'average',
#  'averages',
#  'avfoundation',
#  'avg',
#  'avi',
#  'avoid',
#  'avoided',
#  'avoiding',
#  'avoids',
#  'avplayer',
#  'avplayeritem',
#  'avplayerlayer',
#  'avurlasset',
#  'avx',
#  'await',
#  'awaitable',
#  'awaited',
#  'awaiting',
#  'awaits',
#  'award',
#  'awarded',
#  'aware',
#  'awareness',
#  'away',
#  'awesome',
#  ...]

# %%
# Enregistrement des indices des termes dans l'ordre de leur importance
indices = np.argsort(tfidf_vectorizer.idf_)

# Récupère les termes les plus fréquents
most_frequent_terms = [term for term, index in tfidf_vectorizer.vocabulary_.items() if index in indices[:30]]

# Récupère les termes les moins fréquents
least_frequent_terms = [term for term, index in tfidf_vectorizer.vocabulary_.items() if index in indices[-30:]]

print("Les termes les plus fréquents :", most_frequent_terms)
print()
print("Les termes les moins fréquents :", least_frequent_terms)
# Out:
# Les termes les plus fréquents : ['error', 'trying', 'use', 'make', 'tried', 'using', 'work', 'like', 'way', 'string', 'function', 'know', 'need', 'method', 'question', 'following', 'class', 'new', 'set', 'dont', 'data', 'file', 'return', 'code', 'problem', 'doesnt', 'application', 'ive', 'want', 'example']
#
# Les termes les moins fréquents : ['locales', 'localdate', 'locationmanagermanager', 'zzz', 'locationid', 'locationreload', 'loaderresolve', 'loadergetmodulejob', 'locationmanagerdelegate', 'locating', 'logerror', 'locationpathname', 'localdatetime', 'localhostadmin', 'lockobj', 'locklockobj', 'lockguard', 'logdtag', 'localizable', 'locationresources', 'localfile', 'logback', 'logetag', 'locals', 'localstrategy', 'lockobject', 'localpath', 'loggerisdebugenabled', 'logincomponent', 'locs']

# %%
# Revisité: https://www.geeksforgeeks.org/how-to-calculate-jaccard-similarity-in-python/

# Initialiser une liste pour stocker les scores Jaccard de chaque document
jaccard_scores = []

# Boucle à travers chaque ligne de données
for index, row in data.iterrows():
    # Convertir les tags et les termes du document en ensembles
    true_tags = set(row['Tags'])

    # Obtenir les termes prédits avec leurs poids (scores) du modèle LDA
    predicted_terms_with_scores = best_lda_model.transform(tfidf_vectorizer.transform([row['Title_Body']]))
    
    # Sélectionner les termes avec un score seuil (par exemple, 0.2, ajustez selon vos besoins)
    threshold = 0.2
    predicted_terms_indices = predicted_terms_with_scores.argsort()[0][::-1]  # Obtenez les indices triés par score décroissant
    predicted_terms = set(tfidf_vectorizer.get_feature_names_out()[predicted_terms_indices[:10]])  # Choisissez les 10 premiers termes
    
    # Calculer l'intersection et l'union
    intersection = true_tags.intersection(predicted_terms)
    union = true_tags.union(predicted_terms)
    
    # Calculer le score Jaccard et l'ajouter à la liste
    jaccard_score = float(len(intersection)) / float(len(union))
    jaccard_scores.append(jaccard_score)

# Calculer la moyenne des scores Jaccard
average_jaccard_score = sum(jaccard_scores) / len(jaccard_scores)
print(f"Moyenne des scores Jaccard en non supervisé: {average_jaccard_score}")
# Out:
# Moyenne des scores Jaccard en non supervisé: 0.0
